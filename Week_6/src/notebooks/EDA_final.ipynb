# %%
import pandas as pd
df = pd.read_csv("../data/processed/final.csv")
df.shape
# Out:
# (2500, 17)

# %%
df.isnull().sum()
# Out:
# gender                   0
# age                      0
# region                   0
# tenure_months            0
# contract_type            0
# internet_service         0
# monthly_gb_download      0
# streaming_package        0
# tech_support_calls       0
# payment_method           0
# monthly_charges          0
# late_payments            0
# account_manager          0
# credit_score             0
# churn_label              0
# credit_score_missing     0
# days_since_last_login    0
# dtype: int64

# %%
df.isnull().mean() * 100
# Out:
# gender                   0.0
# age                      0.0
# region                   0.0
# tenure_months            0.0
# contract_type            0.0
# internet_service         0.0
# monthly_gb_download      0.0
# streaming_package        0.0
# tech_support_calls       0.0
# payment_method           0.0
# monthly_charges          0.0
# late_payments            0.0
# account_manager          0.0
# credit_score             0.0
# churn_label              0.0
# credit_score_missing     0.0
# days_since_last_login    0.0
# dtype: float64

# %%
import matplotlib.pyplot as plt
df.select_dtypes(include="number").hist(
    bins=30,
    figsize=(14,10),
    edgecolor="black"
)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
corr = df.select_dtypes(include="number").corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr, cmap="coolwarm", annot=False)
plt.show()

# %%
corr["churn_label"].sort_values(ascending=False)
# Out:
# churn_label              1.000000
# monthly_charges          0.090336
# monthly_gb_download      0.043067
# days_since_last_login    0.034325
# late_payments            0.033879
# credit_score_missing     0.005947
# age                      0.000076
# credit_score            -0.020661
# tech_support_calls      -0.058994
# tenure_months           -0.154851
# Name: churn_label, dtype: float64

# %%
import matplotlib.pyplot as plt

df.select_dtypes(include="number").plot(
    kind="box",
    figsize=(14,6),
    rot=45
)
plt.tight_layout()
plt.show()
